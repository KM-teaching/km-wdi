# %% [markdown]
# ---
# title: Flowchart
# subtitle: Flowchart - ćwiczenia z algorytmiki (3)
# author:
#   - name: Krzysztof Molenda
#     affiliations: URK/WIPiE/KIPLiIS
#     email: krzysztof.molenda@urk.edu.pl
# date: 2026/03/02
# ---
#
# ---

# %% [markdown]
# * Imię i nazwisko, kierunek, grupa: ..................

# %% [markdown]
# ```{note} Informacja
# 1. Aby edytować komórkę, dwukrotnie w nią kliknij
# 2. Po zakończeniu edycji "zamknij komórkę" wybierając <kbd>Shift</kbd> + <kbd>ENTER</kbd>, lub klikając w przycisk **Run cell** ▶ w pasku zadań notatnika.
# 3. Po rozwiązaniu i wypełnieniu pobierz plik (**⤓**Download) na swój dysk i prześlij do oceny.
# ```

# %% [markdown]
# ## Zadanie 3. Schemat blokowy dla pseudokodu
#
# ### 3.1. Narysuj schemat blokowy algorytmu zapisanego pseudokodem
#
# ```pseudocode
# czytaj(a)
# repeat
#   if a mod 3 = 0 then pisz(a)
#   a ← a div 2
# until a = 0
# ```

# %% [markdown]
# ```{tip} Instrukcja:
# 1. Wykorzystaj środowisko Mermaid <https://mermaid.live/edit> do eksperymentowania.
# 2. Edytuj i zmodyfikuj poniższy diagram.
# 3. Więcej informacji o kodowaniu diagramów w formacie mermaid: <https://mermaid.js.org/ecosystem/tutorials.html>
# ```

# %% [markdown]
# ```mermaid
# flowchart TB
#     A((Start)) --> B@{ shape: card, label: "wczytaj całkowite\n a, b"}
#     B --> C{Czy b = 0 ?}
#     C -- Tak --> D[Poproś o wprowadzenie b ponownie]
#     D --> C
#     C -- Nie --> E[wynik = a / b]
#     E --> F@{ shape: doc, label: "Wypisz wynik"}
#     F --> G(((Stop)))
# ```

# %% [markdown]
# ### 3.2. Zapisz ten program w pseudokodzie, ale bez użycia instrukcji `repeat ...` - użyj instrukcji `while`, zadbaj, aby Twój program był równoważny podanemu

# %% [markdown]
# ```pseudocode
# czytaj(a)
# ...
# ```

# %% [markdown]
# ### 3.3. Co wypisze powyższy program, jeżeli jako `a` wczytamy wartość `23`?

# %% [markdown]
# Podaj wynik: ...

# %% [markdown]
# ### 3.4. Zapisz program w Python. Przetestuj go dla różnych zestawów danych.

# %%
# Kod w python
